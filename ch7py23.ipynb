# %% [markdown]
# # Unit :7 Modules & Directories

# %% [raw]
# os model
# 1)getcwd() current path return
# 2 mkdir() make direcy , current locate  ,or give locate , already exist folder give error
# 3 rmdir()# error when no file there # folder
# 4 listdir()
# 5 remove()#file
# 6 chdir()

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\chaitanya\Degree Python

# %%
os.mkdir("week7")
os.mkdir(r"week7/day1")

# %%
os.mkdir("day1")

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\chaitanya\Degree Python

# %%
os.mkdir(r"C:\Users\chaitanya\Desktop\week10")

# %%
os.mkdir(r"C:\Users\LJENG\Desktop\week10") #raw ("r") string to remove cofusen \n \new

# %%
import os
os.rmdir("week7")# not delete bcz inside day1 file

# %%
os.rmdir("day1")# u are not on current path so give path like week7 day1

# %%
os.rmdir(r"week7/day1") # give sequence path for delete

# %%
import os
os.rmdir("week7")

# %%
import os
os.rmdir(r"C:\Users\chaitanya\Desktop\week10")

# %%
import os
print(os.listdir())
# Out:
# ['.ipynb_checkpoints', '01_hello_streamlit.py', '02_layout_basics.py', '05_selection_widgets.py', '06_date_time_file.py', '07_buttons_demo.py', '08_display_data.py', '10_status_demo.py', '11_matplotlib_basic.py', '12_matplotlib_vs_builtin.py', '15_Que.ipynb', '15_QUESTIONS.ipynb', '475.txt', '480.txt', '480f2.txt', 'all9CODES.ipynb', 'BMI_Calculator_APP.py', 'cal.py', 'Ch-10 Matplotlib.ipynb', 'Ch-10 Streamlit.ipynb', 'ch10💕.ipynb', 'ch4immutable (1).ipynb', 'ch4mcq.ipynb', 'ch5MCQ.ipynb', 'ch5mutable (3).ipynb', 'Ch6_files (3).ipynb', 'Ch6_files (4).ipynb', 'ch7py23.ipynb', 'ch8MCQ.ipynb', 'CH8_Exception Handling& OOP (1) (1) (2) (1) (1).ipynb', 'Ch9 Add.ipynb', 'Ch9 Advance Concept of Oop (1) (1) (1)👑.ipynb', 'Ch9 Advance Concept of Oop (1).ipynb', 'Ch9 Advance Concept of Oop.ipynb', 'ch9_MCQ.ipynb', 'chaiatanyaCh2 (2).ipynb', 'chaitanyach1.ipynb', 'chaitanyach3.ipynb', 'City.txt', 'city2.txt', 'city3.txt', 'Cust_data.txt', 'D2.txt', 'D4.txt', 'Demo.txt', 'Demo2.txt', 'Desktop', 'E
# ...

# %%
import os
print(os.listdir(r"C:\Users\chaitanya\Desktop"))

# %%
os.mkdir(r"C:\Users\chaitanya\Desktop\demo5.txt")

# %%
# import os
# os.remove((r"C:\Users\LJENG\Desktop\demo5.txt"))#file
import os
os.remove((r"C:\Users\chaitanya\Desktop\dem5.txt"))#file

# %%
import os
os.rmdir(r"C:\Users\chaitanya\Desktop\demo5.txt")#Folder

# %%
import os
#os.chdir(r"D:\ved\week1") # changing directory C: to D:

print(os.getcwd())
#os.mkdir("day 27")Cannot create a file when that file already exists: 'day 27'
os.rmdir("day 27")
# Out:
# C:\Users\chaitanya\Degree Python

# %% [markdown]
# # datetime module

# %% [raw]
# class date:
#     def today():
#         def f1
#
#         class time
#
#         class datetime

# %% [raw]
# 1)import os
# 2)import datetime as dt
# 3)from datetime import *

# %%
from datetime import date
t=date.today()
print(t)
# Out:
# 2025-12-15

# %%
from datetime import date
t=date(2050,11,12)
print(t)

# %%
from datetime import date
t=time(5,50,15)
print(t)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 2
#       1 from datetime import date
# ----> 2 t=time(5,50,15)
#       3 print(t)
#
# NameError: name 'time' is not defined

# %%
from datetime import time
t=time(5,50,15)
print(t)
# Out:
# 05:50:15

# %%
from datetime import time
t=time(5,50,15,1)
print(t)
# Out:
# 05:50:15.000001

# %%
from datetime import datetime
n=datetime.now()
print(n)

# %% [raw]
#  498  Write a python program to make a module named cal.py which contain all the basic functions related to calculator like
# addition, subtraction, multiplication, and division import that module in another file and use that functions with number
# inputs given by user.

# %%
import os
os.chdir(r"C:")

# %%
from cal import*
x=int(input("Enter:"))
y=int(input("Enter:"))


mul(x,y)
# Out:
# Enter: 5
# Enter: 5
# 25

# %% [raw]
# 499 Write a program to create a module ‘first_word.py’, which returns the first word of any string passed. Show the working
# of the module, by calling the module with any suitable example.
#  Input: ‘This is Python Programming’
#  Output: ‘This’

# %%
from str499 import*
# Out:
# StringW: This is Python Programming
# This

# %%
A=100
def add(a,b):  
      print("The Sum:",a+b)                                
def product(a,b):   
      print("The Product:",a*b) 
                                 
from mymod import*   
print(X)   
add(10,20)   
product(10,20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 8
#       5       print("The Product:",a*b)
#       7 from mymod import*
# ----> 8 print(X)
#       9 add(10,20)
#      10 product(10,20)
#
# NameError: name 'X' is not defined

# %%
A=100
def add(a,b):  
      print("The Sum:",a+b)                                
def product(a,b):   
      print("The Product:",a*b) 
                                 
from mymod import*   
print(A)   
add(10,20)   
product(10,20)
# Out:
# 100
# The Sum: 30
# The Product: 200

# %%
A=100
def add(a,b):  
      print("The Sum:",a+b)                                
def product(a,b):   
      print("The Product:",a*b) 
                                 
from mymod import*   
 
add(10,20)   
product(10,20)
print(X)
# Out:
# The Sum: 30
# The Product: 200
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 11
#       9 add(10,20)
#      10 product(10,20)
# ---> 11 print(X)
#
# NameError: name 'X' is not defined

# %%
A=100
def add(a,b):  
      print("The Sum:",a+b)                                
def product(a,b):   
      print("The Product:",a*b) 
                                 
from mymod import*   
 
add(10,20)   
product(10,20)
# Out:
# The Sum: 30
# The Product: 200

# %%
from mod1 import change as sq
from mod2 import change  as db
#main
s=[1,2,3]
#change(s)
sq(s)
db(s)
# Out:
# [2, 4, 6]
# [1, 4, 9]
