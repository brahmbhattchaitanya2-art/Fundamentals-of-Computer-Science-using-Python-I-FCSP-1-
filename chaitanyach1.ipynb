# %% [markdown]
# # Unit 1
# ## Introduction to Python
# #### Features of python
# 1. High level
# 2. Easy and flexible(',")
# 3. OOP as well as POP
# 4. Dynamically Typed
# 5.compiled(portable by byte code ,check entire code) as well as interpreted(check line by line)

# %%
c = 5
print (c)
print(type(c))

#b = 5.1
print (b)
print(type(b))

#c = "7"
print (c)
print(type(c))

# %%
b=6
print(a+b)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d5a2d708ef51> in <module>
#       1 b=6
# ----> 2 print(a+b)
#
# NameError: name 'a' is not defined

# %%
a=[]
b=[]
print(id(a))
print(id(b))
# Out:
# 1544938371264
# 1544938182592

# %%
num = input('Enter:')# input always return string use int(),float()
print(type(num))
# Out:
# Enter: 25
# <class 'str'>

# %%
_=5
print(_)
# Out:
# 5

# %%
a,b,c=5
print(a,b,c)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-45ffe430dacc> in <module>
# ----> 1 a,b,c=5
#       2 print(a,b,c)
#
# TypeError: cannot unpack non-iterable int object

# %%
a=5,6,7,8,9
print(a)
# Out:
# (5, 6, 7, 8, 9)

# %% [markdown]
# # Type casting

# %%
num ='5'
a= int(num)
print(a,type(a))
# Out:
# 5 <class 'int'>

# %%
num ='6.2'
a= int(num)
print(a,type(a))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-4d5cfc167507> in <module>
#       1 num ='6.2'
# ----> 2 a= int(num)
#       3 print(a,type(a))
#
# ValueError: invalid literal for int() with base 10: '6.2'

# %%
num ='a'
a= int(num)
print(a,type(a))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-9a543a3c003b> in <module>
#       1 num ='a'
# ----> 2 a= int(num)
#       3 print(a,type(a))
#
# ValueError: invalid literal for int() with base 10: 'a'

# %%
num =0.9
a= int(num)
print(a,type(a))
# Out:
# 0 <class 'int'>

# %%
num =True
a= int(num)
print(a,type(a))
# Out:
# 1 <class 'int'>

# %%
num ='5'
a= float(num)
print(a,type(a))
# Out:
# 5.0 <class 'float'>

# %%
num =True
a= float(num)
print(a,type(a))
# Out:
# 1.0 <class 'float'>

# %%
num = 'a'
a= float(num)
print(a,type(a))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-a213fe3dd65c> in <module>
#       1 num = 'a'
# ----> 2 a= float(num)
#       3 print(a,type(a))
#
# ValueError: could not convert string to float: 'a'

# %%
num ='2.55.56'
a= float(num)
print(a,type(a))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-8734cabae76a> in <module>
#       1 num ='2.55.56'
# ----> 2 a= float(num)
#       3 print(a,type(a))
#
# ValueError: could not convert string to float: '2.55.56'

# %%
num =2
a= str(num)
print(a,type(a))
# Out:
# 2 <class 'str'>

# %%
num =100.2
a= str(num)
print(a,type(a))
# Out:
# 100.2 <class 'str'>

# %%
num =True
a= str(num)
print(a,type(a))
# Out:
# True <class 'str'>

# %%
num = 100.2@5
a= str(num)
print(a,type(a))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-a060f0c06570> in <module>
# ----> 1 num = 100.2@5
#       2 a= str(num)
#       3 print(a,type(a))
#
# TypeError: unsupported operand type(s) for @: 'float' and 'int'

# %%
num =5
a= bool(num)
print(a,type(a))
# Out:
# True <class 'bool'>

# %%
num =0
a= bool(num)
print(a,type(a))
# Out:
# False <class 'bool'>

# %%
num =0.4515
a= bool(num)
print(a,type(a))
# Out:
# True <class 'bool'>

# %%
num = ''
a= bool(num)
print(a,type(a))
# Out:
# False <class 'bool'>

# %%
print(True + False)
# Out:
# 1

# %%
print(True + False/False)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-42-3b61d60c84e2> in <module>
# ----> 1 print(True + False/False)
#
# ZeroDivisionError: division by zero

# %%
print(True + False/True)
# Out:
# 1.0

# %%
print(True + False/5)
# Out:
# 1.0

# %% [markdown]
# # Arithmetic operations

# %%
a =50
b=2
print(a/b)
# Out:
# 25.0

# %%
a =50
b=3
print(a/b)
print(a//b)
# Out:
# 16.666666666666668
# 16

# %%
a =50.2
b=3.1
print(a/b)
print(a//b)
# Out:
# 16.193548387096776
# 16.0

# %% [markdown]
# # boolean

# %%
a =True
b=False
print(a/b)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-8-9e003d675b19> in <module>
#       1 a =True
#       2 b=False
# ----> 3 print(a/b)
#
# ZeroDivisionError: division by zero

# %%
a =False
b=True
print(a/b)
# Out:
# 0.0

# %%
a =False
b=True
print(a*b)
# Out:
# 0

# %%
a =False
b=True
print(a//b)
# Out:
# 0

# %%
a =False
b=True
print(a%b)
# Out:
# 0

# %%
a =False
b=True
print(a**b)
# Out:
# 0

# %% [markdown]
# # string

# %%
a = 'Java'
b= 'Python'
print(a+b)
print(a,b)
# Out:
# JavaPython
# Java Python

# %%
a = 'Java'
b= 'Python'
print(a+b)
print(a,b,a,a,sep='__*$__')
print("Hello",a,"this is",b,)
print(a,end= "#")
print(b)
print(a,b)
#print(a*b)
print(a*5)
# Out:
# JavaPython
# Java__*$__Python__*$__Java__*$__Java
# Hello Java this is Python
# Java#Python
# Java Python
# JavaJavaJavaJavaJava

# %% [markdown]
# # assignment operater

# %%
a=5
b=1
a+=b


print(a)
# Out:
# 6

# %%
a=5
a**=2
print(a)
# Out:
# 25

# %%
a=5
print(a**=2)#not possible in print parameter
# Out:
#   File "<ipython-input-31-29203b6cc7da>", line 2
#     print(a**=2)
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
# #  comparison operations

# %%
print ('Hello'> 'ahmedabad')
# Out:
# False

# %%
print(ord("A"))

print(ord("Z"))
print(ord("a"))
print(ord("z"))
# Out:
# 65
# 90
# 97
# 122

# %%
print(chr(89))
# Out:
# Y

# %%
print ('Hello'> 'Hhmedabad')
# Out:
# False

# %%
print ('Hello'=='Hhmedabad')# check everything length data type for ==
# Out:
# False

# %% [markdown]
# # logical

# %%
a=6
b=0.0 # return bcz false by non zero value
c='py'
print(a and b and c)
# Out:
# 0.0

# %%
a=6
b=0.01
c='py'# return bcz all are true
print(a and b and c)
# Out:
# py

# %%
a=0
b=0.01
c='py'# return bcz all are true
print(a or  b or c)
# Out:
# 0.01

# %%
a=6
b=0.01
c='py'
print(a or  b or c)
# Out:
# 6

# %%
a=0
b=0.01
print (not (a or b ))
# Out:
# False

# %%
a=0
b=0.01
c='py'
print(a and  b) or (b and c)
# Out:
# 0
# 'py'

# %%
a=0
b=0.01
c='py'
print(not((a and  b) or (b and c)))
# Out:
# False

# %% [markdown]
# # membeship operations

# %%
print("e " in "python")
print("e " not in "python")
# Out:
# False
# True

# %%
print(2**3**2)
# Out:
# 512

# %% [markdown]
# # example

# %%
num = input("Enter seconds:")
a = int(num)
b= a//60
print(b)
# Out:
# Enter seconds:1
# 0

# %%
sec = int (input ("Enter:"))
minutes = sec //60
hrs = minutes //60
minutes1 = minutes % 60 
sec= sec% 60
#hrs1 =hrs // 60
#print ("Minutes:",minutes1)
#print("hrs:",hrs)
print(hrs,minutes1,sec,sep=":")
# Out:
# Enter:3663
# 1:1:3
