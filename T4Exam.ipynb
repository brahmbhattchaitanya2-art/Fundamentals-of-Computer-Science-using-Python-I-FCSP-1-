# %%
# def to_minutes(t):
#     h, m = map(int, t.split(":"))
#     return h * 60 + m


f = open("newlog.txt", "r")
lines = f.readlines()
f.close()
#print(lines)
users = []

print("Extracted Data:")
for line in lines:
    parts = line.split()
    #print("-------------")
    #print(parts)

    first = parts[0]
    last = parts[1]
    login = parts[2]
    logout = parts[3]

    # initials
    initials = first[0].upper() + last[0].upper()

    print(initials, login, logout)

    #users.append((initials, login, logout))


# print("\nUsers online ≥ 1 hour:")

# for u in users:
#     initials, login, logout = u

#     start = to_minutes(login)
#     end = to_minutes(logout)

#     duration = end - start

#     if duration >= 60:
#         h = duration // 60
#         m = duration % 60
#         print(f"{initials} {login} {logout} ({h}h {m}m)")
# Out:
# Extracted Data:
# GR 14:22 14:37
# BS 08:22 09:10
# DR 11:23 13:05
# NW 13:47 16:33
# YM 08:05 10:23
# JG 12:14 13:47
