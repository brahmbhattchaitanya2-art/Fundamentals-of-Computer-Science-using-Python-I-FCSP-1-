# %%
#names2 = names1 → both point to the same list (no new copy).

#names3 = names1[:] → makes a new independent copy of the list.


names1 = ['Amir', 'Bear', 'Charlton', 'Daman']
names2 = names1
names3 = names1[:]
names2[0] = 'Alice'
names3[1] = 'Bob'
sum = 0
for ls in (names1, names2, names3):
 if ls[0] == 'Alice':
     sum += 1
 if ls[1] == 'Bob':
     sum += 10
print(sum)
# Out:
# 12

# %%
names1 = ['Amir', 'Bear', 'Charlton', 'Daman']
names2 = names1
names3 = names1
names2[0] = 'Alice'
names3[1] = 'Bob'
sum = 0
for ls in (names1, names2, names3):
 if ls[0] == 'Alice':
     sum += 1
 if ls[1] == 'Bob':
     sum += 10
print(sum)
# Out:
# 33

# %%
names1 = ['A', 'B', 'C', 'D'] # same   ['AA', 'B', 'C', 'D']     =2
names2 = names1               # same   ['AA', 'B', 'C', 'D']     =2
names3 = names1[:]            # ['A', 'BB', 'C', 'D'] =          20
names2[0] = 'Aa'
names3[1] = 'BB'
sum = 0
for s in (names1, names2, names3):
 if s[0] == 'Aa':
     sum += 2
 if s[1] == 'BB':
     sum += 20
print(sum)                               # 2+2+20 =24
# Out:
# 24

# %%
def list_transformation():
    alist = [4, 2, 8, 6, 5]
    blist = []
    for item in alist:
        blist.append(item + 5)
    return blist
print(list_transformation())
# Out:
# [9, 7, 13, 11, 10]

# %% [markdown]
# # 337

# %%
def mystery(num_list):
 out = []
 for num in num_list:
     if num > 10:
         out.append(num)
 return out
print(mystery([5, 10, 15, 20]))
# Out:
# [15, 20]

# %% [markdown]
# # 341

# %%
list1 = [1,2,3,4]
list2 = [2,4,5,6]
list3 = [2,6,7,8]       # give that value which not present in other
result = list()
result.extend(i for i in list1 if i not in (list2+list3) and i not in result)
result.extend(i for i in list2 if i not in (list1+list3) and i not in result)
result.extend(i for i in list3 if i not in (list1+list2) and i not in result)
print(result)
# Out:
# [1, 3, 5, 7, 8]

# %%
list1 = [1,2,3,4]
list2 = [2,4,5,6]      # give that value which present in other
list3 = [2,6,7,8]
result = list()
result.extend(i for i in list1 if i in (list2+list3) and i not in result)
result.extend(i for i in list2 if i in (list1+list3) and i not in result)
result.extend(i for i in list3 if i in (list1+list2) and i not in result)
print(result)
# Out:
# [2, 4, 6]

# %%
veggies = ['carrot', 'broccoli', 'potato', 'asparagus']
veggies.insert(veggies.index('broccoli'), 'celery')
print(veggies)
# Out:
# ['carrot', 'celery', 'broccoli', 'potato', 'asparagus']

# %%
list1=[3,2,5,7,3,6]
list1.pop(3)
print(list1)
# Out:
# [3, 2, 5, 3, 6]

# %%
Tup=[2,3,4,[]]
Tup[-1].extend(range(5,35,5))
Tup[-1].append([10,20])
Tup[-1][-1].append([100,200])
print(len(Tup)+len(Tup[3])+len(Tup[-1][-1])+Tup[-1][-2])
# Out:
# 44

# %%
d = {"john":40, "peter":45}
"john" in d
# Out:
# True

# %%
d = {"john":40, "peter":45}
"johiiiin" in d
# Out:
# False

# %%
d = {0: 'a', 1: 'b', 2: 'c'}
for i in d:
 print(i)
# Out:
# 0
# 1
# 2

# %%
d = {"john":40, "peter":45}
d["john"]
# Out:
# 40

# %%
d = {"john":40, "peter":45,"hello":1}
len(d)
# Out:
# 3

# %%
a=dict()
a[1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[43], line 2
#       1 a=dict()
# ----> 2 a[1]
#
# KeyError: 1

# %%
a={ }
a[2]=1
a[1]=[2,3,4]
print(a[1][1])
print(a)
# Out:
# 3
# {2: 1, 1: [2, 3, 4]}

# %%
numbers = {}
letters = {}
comb = {}
numbers[1] = 56
numbers[3] = 7
letters[4] = 'B'
comb['Numbers'] = numbers
comb['Letters'] = letters
print(comb)
# Out:
# {'Numbers': {1: 56, 3: 7}, 'Letters': {4: 'B'}}

# %%
a={1:"A",2:"B",3:"C"}
b=a.copy()
b[2]="D"
print(a)
print(b)
# Out:
# {1: 'A', 2: 'B', 3: 'C'}
# {1: 'A', 2: 'D', 3: 'C'}

# %%
a={1:"A",2:"B",3:"C"}
print(a.get(1))
# Out:
# A

# %%
a={1:"A",2:"B",3:"C"}
print(a.get(1,2))
# Out:
# A

# %%
a={1:"A",2:"B",3:"C"}
print(a.get(4,1))# 4 is not so 1 print
# Out:
# 1

# %%
Dictionary1 = {'A': 'Geeks', 'B': 'For', 'C': 'Geeks'}
print(Dictionary1.keys())
# Out:
# dict_keys(['A', 'B', 'C'])

# %%
dictionary = {"raj": 2, "striver": 3, "vikram": 4}
print(dictionary.values())
# Out:
# dict_values([2, 3, 4])

# %%
a={4,5,6}
b={2,8,6}
a+b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[64], line 3
#       1 a={4,5,6}
#       2 b={2,8,6}
# ----> 3 a+b
#
# TypeError: unsupported operand type(s) for +: 'set' and 'set'

# %%
a={4,5,6}
b={2,8,6}
a-b
# Out:
# {4, 5}

# %%
x = {"apple", "banana", "cherry"}
y = {"google", "microsoft", "apple"}
z = x.union(y)
print(z)
# Out:
# {'cherry', 'google', 'apple', 'banana', 'microsoft'}

# %%
s="Python Programming"
print(len(set(s)))
print(len((s)))
print((set(s)))
# Out:
# 12
# 18
# {'m', 'g', 'a', ' ', 'P', 'i', 'h', 'y', 't', 'r', 'o', 'n'}

# %%
def current_date(**kwargs):
 for i in kwargs:
     print(i)
current_date(date=2-1-2023)
# printing key value
# Out:
# date

# %%
def f1(*m):
 sum1=len(m)   #1,2,3,true 4,=4, , false 5,=5   len 5 itmes
 for i in m:
     sum1+=i
 return sum1 
x=f1(1,2,3,(4,)==(4,),(5,)==(5))
print(x)
# Out:
# 12

# %%
lamb = lambda x: x ** 3
print(lamb('5'))   # da error lambda
# Out:
#   Cell In[86], line 2
#     print(lambda('5'))
#                 ^
# SyntaxError: invalid syntax

# %% [markdown]
# # 390

# %%
numberGames = {}
numberGames[(1,2,4)] = 8
numberGames[(4,2,1)] = 10
numberGames[(1,2)] = 12
sum = 0
for k in numberGames:
 sum += numberGames[k]
print (len(numberGames) + sum)
# Out:
# 33

# %% [markdown]
# # 407

# %%
tuple = {}
tuple[(1,2,4)] = 8
tuple[(4,2,1)] = 10
tuple[(1,2)] = 12
_sum = 0
for k in tuple:
 _sum += tuple[k]
print(len(tuple) + _sum)

# %%
L=[['Physics',101],['Chemistry',202],['Maths',303],45,6,'j']
print(len(L))
# Out:
# 6

# %%
l=[[["hello","0hel"],"bh"],"nm"]
print(l[0][0])
# Out:
# ['hello', '0hel']

# %%
d={1:"welcome",[1]:{1:2}}
print(d[[1]])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 d={1:"welcome",[1]:{1:2}}
#       2 print(d[[1]])
#
# TypeError: unhashable type: 'list'

# %% [markdown]
# # 334

# %%
numbers = [1, 2, 3, 4]
numbers1=numbers.append([5,6,7,8])
print(len(numbers))
print((numbers))
# Out:
# 5
# [1, 2, 3, 4, [5, 6, 7, 8]]

# %% [markdown]
# # 335

# %%
a=[1,2,3]
b=a.append(4)

print(a)
print(b)
# Out:
# [1, 2, 3, 4]
# None

# %%
a=[1,2,3]
b=a.append(4)
b=a
print(a)
print(b)
# Out:
# [1, 2, 3, 4]
# [1, 2, 3, 4]

# %%
def F(B,A=3,*C,**D):
 sum=A+B
 for i in C:
     sum=sum+i
 for i in D.values(): 
     sum=sum+i
 return sum
print(F(1,5,7,4,3,e=1,f=2))    #----sum 1+5+7+4+3+1+2+=23
# Out:
# 23

# %%
list1=[1,2,3,4]
list2=[5,6,7,8]
print(len(list1+list2-list1+list2))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 3
#       1 list1=[1,2,3,4]
#       2 list2=[5,6,7,8]
# ----> 3 print(len(list1+list2-list1+list2))
#
# TypeError: unsupported operand type(s) for -: 'list' and 'list'

# %%
list1=[1,2,3,4]
list2=[5,6,7,8]
print(len(list1+list2+list1+list2))
# Out:
# 16

# %% [markdown]
# # 412

# %%
def writer():
 title = 'Sir'
 name = (lambda x: title + ' ' * 2x)
 return name
who = writer()
print(who('Arthur'))
# Out:
#   Cell In[34], line 3
#     name = (lambda x: title + ' ' * 2x)
#                                     ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# # 388

# %%
def writer():
 title = 'Sir'
 name = (lambda x: title + ' ' + x)
 return name
who = writer()
print(who('Arthur'))
# Out:
# Sir Arthur

# %%
names1 = ['A', 'B', 'C', 'D'] # same   ['AA', 'B', 'C', 'D']     =2
names2 = names1               # same   ['AA', 'B', 'C', 'D']     =2
names3 = names1[:]            # ['A', 'BB', 'C', 'D'] =          20
names2[0] = 'Aa'
names3[1] = 'BB'
sum = 0
for s in (names1, names2, names3):
 if s[0] == 'Aa':
     sum += 2
 if s[1] == 'BB':
     sum += 20
print(sum)                               # 2+2+20 =24
# Out:
# 24

# %%
x={1,2,3,4,5}
y={3,4,5,6,7}
z={1,3,5,7,9}
print( (x|y) & (x|z))
# Out:
# {1, 2, 3, 4, 5, 7}

# %%
d={1:"welcome",[1]:{1:2}}
print(d[[1]])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 d={1:"welcome",[1]:{1:2}}
#       2 print(d[[1]])
#
# TypeError: unhashable type: 'list'

# %%
422)



l=[1,2,[[1,2,[1,2],1,2]]]
print(l[2][0])
# Out:
# [1, 2, [1, 2], 1, 2]

# %%
l=[1,2,[[1,2,[1,2],1,2]]]
print(l[2])
# Out:
# [[1, 2, [1, 2], 1, 2]]

# %%
l=[1,2,[[1,2,[1,2],1,2]]]
print(l[2][0][0])
# Out:
# 1

# %% [markdown]
# # 425

# %%
def f(*l):
 for i in l[0]:
     sum=0
     sum+=i
 print(sum)
f([1,2,3])
# Out:
# 3

# %%
def f(*l):
    sum=0
    for i in l[0]:
     sum+=i
    print(sum)
f([1,2,3])
# Out:
# 6

# %%
for k in [0,1,2,3,4,5]:
 print(k)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
lst=[3,4,6,1,2]
print(len(lst))
print(lst[2])
lst[1:2]=[7,8]
#print(lst)
lst.index(1)
# Out:
# 5
# 6
# 4

# %%
a={1:"A",2:"B",3:"C"}
b={4:"D",5:"E"}
a.update(b)
print(a)
# Out:
# {1: 'A', 2: 'B', 3: 'C', 4: 'D', 5: 'E'}

# %%
s="Python Programming"
print(len(set(s)))

print((set(s)))
# Out:
# 12
# {' ', 'i', 'P', 'y', 'r', 'm', 't', 'g', 'o', 'a', 'n', 'h'}

# %%
L1 = [ ]
L1.append([1, [2, 3], 4])
L1.extend([7, 8, 9])
print(L1)
print(L1[0][1][1] + L1[2])
print(L1[2])
print(L1[0][1][1])
# Out:
# [[1, [2, 3], 4], 7, 8, 9]
# 11
# 8
# 3

# %%
def sum_list(l):
 sum=0
 for i in range(len(l)):
     if l[i]==13 or l[i-1]==13:
         continue
     else:
         sum+=l[i]
 return sum 
l= [1,2,13,2,9,13]
print(sum_list(l))
# Out:
# 11
