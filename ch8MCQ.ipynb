# %%
class test:
    def __init__(self,a="Hello World"):
     self.a=a
    def display(self):
     print(self.a)
obj=test()
obj.display()
# Out:
# Hello World

# %%
class test:
 def __init__(self,a):
     self.a=a
 def display(self):
     print(self.a)
obj=test()
obj.display()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 6
#       4  def display(self):
#       5      print(self.a)
# ----> 6 obj=test()
#       7 obj.display()
#
# TypeError: test.__init__() missing 1 required positional argument: 'a'

# %%
class Student:
 def __init__(self,id,age):
  self.id=id
  self.age=age
  
     
std=Student(1,20)
# Out:
# 1

# %%
class Student:
 def __init__(self,name,id):
     self.name=name
     self.id=id
     print(self.id)
std=Student("Simon",1)
std.id=2
print(std.id)
# Out:
# 1
# 2

# %%
class A():
 def __init__(self,count=100):
     self.count=count
obj1=A()
obj2=A(102)
print(obj1.count)
print(obj2.count)
# Out:
# 100
# 102

# %%
class A:
 def __init__(self,count):
     self.count=5
     self.count=count+1
a=A(count)
print(a.count)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[66], line 5
#       3      self.count=5
#       4      self.count=count+1
# ----> 5 a=A(count)
#       6 print(a.count)
#
# NameError: name 'count' is not defined

# %%
A=25
B=40
try:
    L=[]
    for i in range(2):
        L.append(A)
    print(L[3])
    L.append(C)
    iff len(L)<5:
        print(L)
    C=34
except IndexError:
    print("Not in range")
except NameError:
    print("Not defined")
except SyntaxError:
    print("Write properly")
# Out:
#   Cell In[1], line 9
#     iff len(L)<5:
#         ^
# SyntaxError: invalid syntax

# %%
A=25
B=40
try:
    L=[]
    for i in range(2):
        L.append(A    # L becomes [25, 25]
    print(L[3])   # <-- ERROR happens here (IndexError)
    L.append(C)
    if len(L)<5:  
        print(L)
    C=34
except IndexError:
    print("Not in range")
except NameError:
    print("Not defined")
except SyntaxError:
    print("Write properly")
# Out:
# Not in range

# %%
def foo():
    try:
        return 1
    finally:
        return 2
k = foo()
print(k)
# Out:
# 2

# %%
def foo():
    try:
        print(1)
    finally:
        print(2)
k = foo()
print(k)
# Out:
# 1
# 2
# None

# %%
def foo():
    try:
        print(1)
    finally:
        print(2)
    return 100
k = foo()
print(k)
# Out:
# 1
# 2
# 100

# %%
def foo(n):
    try:
        print(n)
    finally:
        print(2)
k = foo(3)
print(k)
# Out:
# 3
# 2
# None

# %%
def getMonth(m):
    if m<1 or m>12:
        raise ValueError("Invalid")
    print(m)
getMonth(6)
# Out:
# 6

# %%
def getMonth(m):
    if m<1 or m>12:
        raise ValueError("Invalid")
    print(m)
getMonth(15)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 5
#       3         raise ValueError("Invalid")
#       4     print(m)
# ----> 5 getMonth(15)
#
# Cell In[21], line 3, in getMonth(m)
#       1 def getMonth(m):
#       2     if m<1 or m>12:
# ----> 3         raise ValueError("Invalid")
#       4     print(m)
#
# ValueError: Invalid
